# %% [markdown]
# ## Examining Animal Data

# %% [markdown]
# - Import your libraries (Pandas and NumPy)
# - Import the code as two Data Frames: "intakes" and "outcomes"

# %%
import pandas as pd
import numpy as np

intakes = pd.read_csv('../assets/austin_animal_intakes_15.csv')
outcomes = pd.read_csv('../assets/austin_animal_outcomes_15.csv')

# %%
intakes
# Out:
#       Animal ID          Name Intake Date Intake Time  \
# 0       A689228         Louie    10/01/14      7:21AM
# 1       A689234           NaN    10/01/14      8:44AM
# 2       A689239           NaN    10/01/14      8:44AM
# 3       A689237           NaN    10/01/14      8:44AM
# 4       A689238           NaN    10/01/14      8:44AM
# 5       A689235           NaN    10/01/14      8:44AM
# 6       A689236           NaN    10/01/14      8:44AM
# 7       A689241          Lady    10/01/14     10:05AM
# 8       A688878            Jd    10/01/14     10:19AM
# 9       A689243         Biela    10/01/14     10:57AM
# 10      A689253    Spider Man    10/01/14     11:03AM
# 11      A689246          Lori    10/01/14     11:03AM
# 12      A689255  Spider Woman    10/01/14     11:03AM
# 13      A689252       Emerald    10/01/14     11:03AM
# 14      A689254        Amenia    10/01/14     11:03AM
# 15      A689244          Cass    10/01/14     11:06AM
# 16      A673394          Maya    10/01/14     11:23AM
# 17      A689245          Nala    10/01/14     11:23AM
# 18      A689248         *Jack    10/01/14     11:37AM
# 19      A689249        *Janet    10/01/14     11:37AM
# 20      A689247           NaN    10/01/14     11:37AM
# 21      A689250      *Chrissy    10/01/14     11:37AM
# 22      A689251          Blue    10/01/14     11:38AM
# 23      A663846            Cj    10/01/14     11:46AM
# 24      A689265       Scratch    10/01/14     12:56PM
# 25      A689264       Monarch    10/01/14     12:56PM
# 26      A689257       *Hailey    10/01/14      1:10PM
# 27      A689258           NaN    10/01/14      1:18PM
# 28      A689259           NaN    10/01/14      1:18PM
# 29      A689262         Chavo    10/01/14      1:35PM
# ...         ...           ...         ...         ...
# 18597   A712934           NaN    09/30/15      1:21PM
# 18598   A712936       *Louise    09/30/15      1:23PM
# 18599   A712935       *Thelma    09/30/15      1:23PM
# 18600   A712937       Artemis    09/30/15      1:30PM
# 18601   A712939           NaN    09/30/15      1:39PM
# 18602   A712941      *Claudio    09/30/15      1:59PM
# 18603   A697974    Sugar Mama    09/30/15      2:01PM
# 18604   A712942          Pete    09/30/15      2:17PM
# 18605   A703876       *Conrad    09/30/15      2:22PM
# 18606   A676830        Butter    09/30/15      3:02PM
# 18607   A676832        Cookie    09/30/15      3:02PM
# 18608   A712955       Twinkie    09/30/15      3:02PM
# 18609   A712945         Candy    09/30/15      3:07PM
# 18610   A712947       Grayson    09/30/15      3:14PM
# 18611   A712946        Tenshi    09/30/15      3:14PM
# 18612   A712948         Briah    09/30/15      3:29PM
# 18613   A712949           NaN    09/30/15      3:30PM
# 18614   A712950      *Cricket    09/30/15      3:42PM
# 18615   A699979       Roxanne    09/30/15      3:47PM
# 18616   A712951      *Pontiac    09/30/15      3:54PM
# 18617   A710427   *Cinderella    09/30/15      4:02PM
# 18618   A712958     *Francois    09/30/15      4:23PM
# 18619   A712959          Arby    09/30/15      4:28PM
# 18620   A712963         Oscar    09/30/15      4:30PM
# 18621   A712969        *Jacob    09/30/15      5:33PM
# 18622   A712970           NaN    09/30/15      5:42PM
# 18623   A712971           NaN    09/30/15      5:48PM
# 18624   A712972         Julie    09/30/15      5:53PM
# 18625   A692521          Coby    09/30/15      6:13PM
# 18626   A712944          Blue    09/30/15      6:59PM
#
#                                   Found Location      Intake Type  \
# 0                   3005 S. Lamar in Austin (TX)            Stray
# 1                                    Travis (TX)            Stray
# 2                                    Travis (TX)            Stray
# 3                                    Travis (TX)            Stray
# 4                                    Travis (TX)            Stray
# 5                                    Travis (TX)            Stray
# 6                                    Travis (TX)            Stray
# 7                         Airport in Austin (TX)            Stray
# 8                                    Austin (TX)  Owner Surrender
# 9          3600 Presidential Blvd in Austin (TX)            Stray
# 10                                   Austin (TX)  Owner Surrender
# 11                                   Austin (TX)  Owner Surrender
# 12                                   Austin (TX)  Owner Surrender
# 13                                   Austin (TX)  Owner Surrender
# 14                                   Austin (TX)  Owner Surrender
# 15                                   Austin (TX)  Owner Surrender
# 16               1909 Blue Meadow in Austin (TX)            Stray
# 17                                   Austin (TX)  Owner Surrender
# 18              4601 Craigwood Dr in Austin (TX)            Stray
# 19              4601 Craigwood Dr in Austin (TX)            Stray
# 20              4601 Craigwood Dr in Austin (TX)            Stray
# 21              4601 Craigwood Dr in Austin (TX)            Stray
# 22         Grover Ave & Payne Ave in Austin (TX)            Stray
# 23            2206 Blue Meadow Dr in Austin (TX)            Stray
# 24                                   Austin (TX)  Owner Surrender
# 25              3201 Northeast Dr in Austin (TX)            Stray
# 26             2310 Canterbury St in Austin (TX)            Stray
# 27            3611 Pace Bend Rd S in Travis (TX)            Stray
# 28            3611 Pace Bend Rd S in Travis (TX)            Stray
# 29                           9300 Northgate Blvd           Austin
# ...                                          ...              ...
# 18597       2401 S Lakeshore Blvd in Austin (TX)            Stray
# 18598              16300 Summt Dr in Travis (TX)            Stray
# 18599              16300 Summt Dr in Travis (TX)            Stray
# 18600              12000 Dunfries in Austin (TX)            Stray
# 18601                  2205 Muroc in Austin (TX)            Stray
# 18602                   15709 812 in Austin (TX)            Stray
# 18603                                Austin (TX)  Owner Surrender
# 18604            1602 Webberville in Austin (TX)            Stray
# 18605                                Austin (TX)  Owner Surrender
# 18606                                Austin (TX)  Owner Surrender
# 18607                                Austin (TX)  Owner Surrender
# 18608                                Austin (TX)  Owner Surrender
# 18609  3351 Killingsworth Ln #379 in Austin (TX)            Stray
# 18610                                Austin (TX)  Owner Surrender
# 18611                                Austin (TX)  Owner Surrender
# 18612      1514 Greenfield Dr in Round Rock (TX)            Stray
# 18613       5905 Silver Screen Dr in Austin (TX)            Stray
# 18614               14310 N Ih 35 in Austin (TX)            Stray
# 18615          8603 Fathom Circle in Austin (TX)            Stray
# 18616         9608 North Creek Dr in Austin (TX)            Stray
# 18617         2508 E Riverside Dr in Austin (TX)            Stray
# 18618               405 Heartwood in Austin (TX)            Stray
# 18619                                Austin (TX)  Owner Surrender
# 18620           4646 Mueller Blvd in Austin (TX)            Stray
# 18621                2101 S Ih 35 in Austin (TX)            Stray
# 18622     Jamestown Dr & Maine Dr in Austin (TX)            Stray
# 18623        14517 Amy Francis St in Austin (TX)            Stray
# 18624                  6911 Ih 35 in Austin (TX)            Stray
# 18625               1405 E 4Th St in Austin (TX)            Stray
# 18626                                Austin (TX)    Public Assist
#
#          Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                  Normal         Dog     Intact Male        4 months
# 1                 Nursing         Dog         Unknown         0 years
# 2                 Nursing         Dog         Unknown         0 years
# 3                 Nursing         Dog         Unknown         0 years
# 4                 Nursing         Dog         Unknown         0 years
# 5                 Nursing         Dog         Unknown         0 years
# 6                 Nursing         Dog         Unknown         0 years
# 7                  Normal         Dog   Spayed Female         2 years
# 8                  Normal         Cat   Neutered Male        2 months
# 9                  Normal         Dog   Intact Female         4 years
# 10                 Normal         Cat     Intact Male        7 months
# 11                 Normal         Cat   Spayed Female         2 years
# 12                 Normal         Cat   Spayed Female          1 year
# 13                 Normal         Cat   Spayed Female         2 years
# 14                 Normal         Cat   Spayed Female          1 year
# 15                 Normal         Cat   Spayed Female         4 years
# 16                Injured         Dog   Spayed Female         5 years
# 17                 Normal         Dog   Spayed Female        6 months
# 18                 Normal         Cat     Intact Male         4 weeks
# 19                 Normal         Cat   Intact Female         4 weeks
# 20                 Normal         Cat   Intact Female          1 year
# 21                 Normal         Cat   Intact Female         4 weeks
# 22                 Normal         Dog     Intact Male         2 years
# 23                 Normal         Dog   Neutered Male         3 years
# 24                 Normal         Cat   Intact Female          1 year
# 25                 Normal       Other         Unknown          1 year
# 26                 Normal         Dog   Intact Female         2 years
# 27                 Normal         Cat   Intact Female         3 weeks
# 28                 Normal         Cat     Intact Male         3 weeks
# 29      Tx in Austin (TX)       Stray          Normal             Dog
# ...                   ...         ...             ...             ...
# 18597              Normal         Dog   Intact Female        3 months
# 18598              Normal         Dog   Intact Female          1 year
# 18599              Normal         Dog   Intact Female         7 years
# 18600              Normal         Dog   Intact Female        9 months
# 18601              Normal         Cat         Unknown         2 years
# 18602              Normal         Dog     Intact Male          1 year
# 18603              Normal         Dog   Spayed Female         2 years
# 18604              Normal         Dog     Intact Male         2 years
# 18605              Normal         Dog   Neutered Male         2 years
# 18606              Normal         Dog   Neutered Male          1 year
# 18607              Normal         Dog   Spayed Female          1 year
# 18608              Normal         Dog   Spayed Female          1 year
# 18609             Injured         Dog   Intact Female         4 years
# 18610              Normal         Dog   Spayed Female         6 years
# 18611              Normal         Dog   Spayed Female         6 years
# 18612              Normal         Dog   Intact Female         2 years
# 18613              Normal         Cat     Intact Male          1 year
# 18614              Normal         Dog   Intact Female         3 years
# 18615              Normal         Dog   Spayed Female        9 months
# 18616              Normal         Dog     Intact Male         2 years
# 18617              Normal         Cat   Spayed Female        7 months
# 18618               Other         Cat   Neutered Male        10 years
# 18619              Normal         Dog   Intact Female         5 years
# 18620              Normal         Cat   Neutered Male          1 year
# 18621              Normal         Dog     Intact Male        7 months
# 18624                               Toy Poodle Mix                Cream
# 18625                                 Pit Bull Mix           Fawn/White
# 18626                               Rottweiler Mix                Brown
#
# [18627 rows x 12 columns]

# %%
outcomes
# Out:
#       Animal ID          Name Outcome Date Outcome Time     Outcome Type  \
# 0       A689146           NaN     10/01/14       7:54AM       Euthanasia
# 1       A689208           NaN     10/01/14       7:56AM       Euthanasia
# 2       A689225           NaN     10/01/14       9:00AM         Transfer
# 3       A689202           NaN     10/01/14      11:30AM       Euthanasia
# 4       A684326         Kelvi     10/01/14      11:37AM         Adoption
# 5       A574935          Blue     10/01/14      12:11PM         Transfer
# 6       A575129        Brandi     10/01/14      12:11PM         Transfer
# 7       A688991        Shades     10/01/14      12:25PM         Transfer
# 8       A689108     Andromeda     10/01/14      12:30PM         Adoption
# 9       A689241          Lady     10/01/14      12:53PM  Return to Owner
# 10      A688094         Savvy     10/01/14      12:57PM         Transfer
# 11      A688918         Storm     10/01/14       1:27PM         Adoption
# 12      A689038       Trouble     10/01/14       2:01PM         Transfer
# 13      A684772       *Peanut     10/01/14       2:03PM         Transfer
# 14      A687060         Pablo     10/01/14       2:24PM         Adoption
# 15      A688144        Tarzan     10/01/14       2:26PM         Adoption
# 16      A651258         Ethan     10/01/14       3:03PM  Return to Owner
# 17      A688905           NaN     10/01/14       3:04PM         Transfer
# 18      A688996       *Gibson     10/01/14       3:06PM         Transfer
# 19      A688232        *Sally     10/01/14       3:08PM         Transfer
# 20      A689227           NaN     10/01/14       3:12PM         Transfer
# 21      A689258           NaN     10/01/14       3:12PM         Transfer
# 22      A689259           NaN     10/01/14       3:13PM         Transfer
# 23      A689268           NaN     10/01/14       3:19PM         Transfer
# 24      A689267           NaN     10/01/14       3:23PM         Transfer
# 25      A687211     *Magnolia     10/01/14       3:26PM         Adoption
# 26      A689054       Chappie     10/01/14       3:48PM         Transfer
# 27      A683921           NaN     10/01/14       3:49PM         Transfer
# 28      A688774       *Walter     10/01/14       3:49PM         Transfer
# 29      A688523        *Basil     10/01/14       3:50PM         Transfer
# ...         ...           ...          ...          ...              ...
# 18417   A711733  *Orangesicle     09/30/15      12:11PM         Transfer
# 18418   A711413         *Tina     09/30/15      12:11PM         Transfer
# 18419   A712917           NaN     09/30/15      12:49PM  Return to Owner
# 18420   A712519           NaN     09/30/15      12:50PM         Adoption
# 18421   A712620          *Elf     09/30/15       1:05PM         Adoption
# 18422   A712802        Autumn     09/30/15       1:20PM  Return to Owner
# 18423   A637965       Poppies     09/30/15       1:28PM  Return to Owner
# 18424   A712876           NaN     09/30/15       1:32PM       Euthanasia
# 18425   A712354       *Pearce     09/30/15       2:03PM         Adoption
# 18426   A712913         Teemo     09/30/15       2:17PM  Return to Owner
# 18427   A711128        Amelia     09/30/15       2:29PM         Adoption
# 18428   A711127        Maggie     09/30/15       2:29PM         Adoption
# 18429   A712800         Blake     09/30/15       3:09PM  Return to Owner
# 18430   A712396        *Mario     09/30/15       3:12PM         Adoption
# 18431   A712883       Salaria     09/30/15       4:15PM  Return to Owner
# 18432   A712884      Princess     09/30/15       4:18PM  Return to Owner
# 18433   A355753        Elijah     09/30/15       4:48PM  Return to Owner
# 18434   A712648           Ace     09/30/15       5:30PM         Adoption
# 18435   A712655        *Morty     09/30/15       5:33PM         Adoption
# 18436   A712687        *Jules     09/30/15       5:53PM         Adoption
# 18437   A712645           NaN     09/30/15       5:55PM         Adoption
# 18438   A708791          Lily     09/30/15       5:57PM         Adoption
# 18439   A712945         Candy     09/30/15       5:59PM  Return to Owner
# 18440   A712666           NaN     09/30/15       6:09PM         Adoption
# 18441   A711452           NaN     09/30/15       6:14PM         Adoption
# 18442   A711454           NaN     09/30/15       6:18PM         Adoption
# 18443   A712651           NaN     09/30/15       6:30PM         Transfer
# 18444   A712652           NaN     09/30/15       6:30PM         Transfer
# 18445   A712701           NaN     09/30/15       6:45PM         Adoption
# 18446   A707975           NaN     09/30/15       6:54PM         Adoption
#
#       Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0         Rabies Risk         Cat    Intact Female          1 month
# 1           Suffering         Cat    Neutered Male          2 years
# 2                SCRP         Cat    Intact Female          6 years
# 3         Rabies Risk       Other          Unknown         6 months
# 4                 NaN         Dog    Spayed Female          5 years
# 5             Partner         Dog    Neutered Male         10 years
# 6             Partner         Dog    Spayed Female         10 years
# 7             Partner         Dog      Intact Male          3 years
# 8                 NaN         Cat    Spayed Female          5 years
# 9                 NaN         Dog    Spayed Female          2 years
# 10            Partner         Dog    Intact Female         7 months
# 11                NaN         Cat    Intact Female          1 month
# 12            Partner         Cat      Intact Male          3 years
# 13            Partner         Cat    Neutered Male          9 years
# 14                NaN         Dog    Neutered Male           1 year
# 15                NaN         Dog    Neutered Male           1 year
# 16                NaN         Cat    Neutered Male           1 year
# 17            Partner         Dog    Intact Female          2 years
# 18            Partner         Dog    Neutered Male          2 years
# 19            Partner         Dog    Spayed Female          5 years
# 20            Partner         Cat    Intact Female          2 weeks
# 21            Partner         Cat    Intact Female          3 weeks
# 22            Partner         Cat      Intact Male          3 weeks
# 23            Partner         Cat      Intact Male          3 weeks
# 24            Partner         Cat      Intact Male          3 weeks
# 25                NaN         Cat    Spayed Female          1 month
# 26            Partner         Cat    Spayed Female         7 months
# 27            Partner         Cat    Neutered Male           1 year
# 28            Partner         Cat    Neutered Male        10 months
# 29            Partner         Cat    Spayed Female           1 year
# ...               ...         ...              ...              ...
# 18417         Partner         Cat    Neutered Male        10 months
# 18418         Partner         Cat    Spayed Female         3 months
# 18419             NaN         Dog    Neutered Male          7 years
# 18420             NaN         Dog    Spayed Female           1 year
# 18421             NaN         Dog    Neutered Male           1 year
# 18422             NaN         Dog    Spayed Female         4 months
# 18423             NaN         Dog    Spayed Female          3 years
# 18424       Suffering         Cat      Intact Male          1 month
# 18425             NaN         Dog    Neutered Male           1 year
# 18426             NaN         Dog    Neutered Male           1 year
# 18427             NaN         Cat    Spayed Female         14 years
# 18428             NaN         Cat    Spayed Female         14 years
# 18429             NaN         Dog      Intact Male         2 months
# 18430             NaN         Cat    Neutered Male         3 months
# 18431             NaN         Dog    Spayed Female          3 years
# 18436                       Dachshund Mix             Tricolor
# 18437                       Dalmatian Mix          White/Black
# 18438                   Staffordshire Mix           Blue/White
# 18439             Chihuahua Shorthair Mix            White/Tan
# 18440                        Pit Bull Mix          Black/White
# 18441            Domestic Medium Hair Mix           Blue/White
# 18442            Domestic Medium Hair Mix   Orange Tabby/White
# 18443                       Dachshund Mix       Blue Merle/Tan
# 18444                       Dachshund Mix            Black/Tan
# 18445             Chihuahua Shorthair Mix        Black Brindle
# 18446              Domestic Shorthair Mix           Blue/White
#
# [18447 rows x 11 columns]

# %% [markdown]
# ## Part 1: Tidying Data
# - Handle null values (You can drop, fill, etc., but make sure you make a comment explaining your choice)

# %% [markdown]
# - Rename any columns that could make more sense (or need to be one word)

# %% [markdown]
# - Group the date and time columns into a single column and convert it to datetime objects

# %% [markdown]
# - Convert the data types of any columns in each data frame that should be different

# %% [markdown]
# - Change the values in the breed and color columns into lists

# %% [markdown]
# ## Part 2: Assemble Descriptive Data

# %% [markdown]
# - Make a data frame with all of the permanent descriptive data (animal id, name, animal type, breed, color) from each Data Frame
# - Consider: What is the best way to include data from both data frames? Merge/Join/Concatenate? How?

# %% [markdown]
# - You should now have lots of duplicates. Use the pandas method [drop_duplicates](http://pandas.pydata.org/pandas-docs/version/0.17.1/generated/pandas.DataFrame.drop_duplicates.html) to remove them.

# %% [markdown]
#  - Create a column with the sex (male, female, or unknown) for each animal (hint: choose one of the original data frames, simplify the sex column, and merge on animal id)

# %% [markdown]
# #### Challenge goal
# - Do you have any animals that have mismatched data? Handle this so every animal has a single row describing it.

# %% [markdown]
# ## Part 3: Examine the Descriptive Data

# %% [markdown]
# - How many animal types are there? What are they?

# %% [markdown]
# - Make a bar chart showing the distribution of how many animals are in each animal type category

# %% [markdown]
# - Make a list of all the unique breeds for each animal type (one list for dogs, one list for cats, etc.)

# %% [markdown]
# - For each animal type, make a pie chart showing the distribution of sex

# %% [markdown]
# #### Challenge Goal
# - Get a list of unique colors
# - Create a new dataframe with the number of animals of each color
# - Plot this information
# - EXTRA BONUS: Make each plot correspond to the color it represents!

# %% [markdown]
# ## Part 4: CHALLENGE - Create Timelines

# %% [markdown]
# - Create a new data frame from intakes showing the animal id, intake time, intake type, intake condition, age upon intake, and sex upon intake
# - Do the same for outcomes (instead of intake condition, use outcome subtype)

# %% [markdown]
# - Create a single data frame that is chronological showing all intakes and outcomes, then sort this by animal ID (You should be able to make out a story for each individual by doing this)
# - Consider: Why aren't we just merging on animal ID?

# %% [markdown]
# - Condense this data frame so that for each intake, the same row shows the corresponding outcome for that animal (you may need to drop some information if there is not an even match between intakes and outcomes)

# %% [markdown]
# Answer the following questions:
# - How long do animals spend in the shelter on average?
# - How many animals were "fixed" (Spayed or Neutered) in care?

# %% [markdown]
# ## Part 5: CHALLENGE - Examine the Intake/Outcome Data

# %% [markdown]
# - What outcome is the most likely for each intake type? For each intake condition?
# - Does being male or female affect the outcome?
# - What are the most common outcomes for each animal type?
# - What are the most likely outcome subtypes for each outcome type?
