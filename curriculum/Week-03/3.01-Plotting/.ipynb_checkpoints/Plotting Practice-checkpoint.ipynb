# %% [markdown]
# # Plotting Practice
#
# import libraries and data

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('cereal.csv', error_bad_lines=False, sep=';')

# %%
data[['protein','fat','fiber','carbo','sugars']].plot(kind='bar', figsize=(20,20), stacked=True)
